# %%
# You can follow this tutorial for more information - https://www.tutorialspoint.com/google_colab/index.htm
# You can also see this video - https://www.youtube.com/watch?v=inN8seMm7UI

# Mount your Drive - After doing this step, your Google Drive folders are accessible from Google Colab.
from google.colab import drive
drive.mount('/content/gdrive')

# %%
# Use it as a standard Linux console, by prepending ! to the commands.

# Install all the requirements
# !pip install opencv-python

import tensorflow as tf
print(tf.__version__)
if tf.__version__ != "2.11.0":
  # %pip install tensorflow==2.11.0

# Example of apt-get
# !apt-get install protobuf-compiler python-pil python-lxml python-tk

# Example of setup Tensorflow version
# %tensorflow_version 2.x

# %%
# Move into the folder where you have the script test.py and all you need to run your test
# I downloaded the archive GTA_CAIP_Contest_Code.zip in my Google Drive root /content/gdrive/My Drive/ but you can use different folders.
# %cd "/content/gdrive/MyDrive/Cosenga AV Gruppo 01"

# %%
# Run the test
# --data is the file with the annotations. Use the provided foo_test.csv to check if your code works.
# --images is the path of the folder with the images listed in --data. Use the provided foo_test/ to check if your code works.
# --results is the file on which the predictions of your model should be written. A sample foo_results.csv is provided.
# --model is the path of model's foldet to upload (default = '/ResNet152V2_gr01')
# !python test.py --data foo_test.csv --images foo_test/ --results foo_results.csv
